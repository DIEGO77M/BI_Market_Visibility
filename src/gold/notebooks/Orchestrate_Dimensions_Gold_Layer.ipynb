# %% [markdown]
# #### ===================================================================
# #### GOLD LAYER ORCHESTRATOR
# #### Author: Diego Mayorga
# #### Purpose: Orchestrate Gold Layer tables in order with logs
# #### Notes: Modular, idempotent, ready to add more SQL scripts
# #### ===================================================================

# %%
from datetime import datetime

# ----------------------------------------
# Logging helper
# ----------------------------------------
def log_step(step_name, status, msg=None):
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{timestamp}] [{status}] {step_name}{' - ' + msg if msg else ''}")

# ----------------------------------------
# Run SQL notebook / script safely
# ----------------------------------------
def run_sql(path, step_name):
    try:
        log_step(step_name, "START")
        # dbutils.notebook.run expects notebook path in Databricks
        dbutils.notebook.run(path, 0)
        log_step(step_name, "SUCCESS")
    except Exception as e:
        log_step(step_name, "FAIL", str(e))
        raise e

# %%
# ===================================================================
# STEP 1: Create dim_date (Gold) - Direct SQL execution
# ===================================================================
step_name = "Create dim_date"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/dim_date/create_dim_date_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 2: Create dim_pdv (Gold) - Direct SQL execution
# ===================================================================
step_name = "Create dim_pdv"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/dim_pdv/create_dim_pdv_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 3: Create dim_product_base (Gold) - Direct SQL execution
# ===================================================================
step_name = "Create dim_product_base"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/dim_product/create_dim_product_base_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 3A: Audit dim_product_base (Gold) - Direct SQL execution
# ===================================================================
step_name = "Audit dim_product_base"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/dim_product/create_audit_dim_product_gold_base.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 4: Create metric_price_reference (Gold) - Direct SQL execution
# ===================================================================
step_name = "Create metric_price_reference"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/metric_price_reference/create_metric_price_reference_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 4A: Audit metric_price_reference (Gold) - Direct SQL execution
# ===================================================================
step_name = "Audit metric_price_reference"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/metric_price_reference/create_audit_metric_price_reference_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 5: Create dim_product (Gold) - Direct SQL execution
# ===================================================================
step_name = "Create dim_product"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/dim_product/create_dim_product_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 5A: Audit dim_product (Gold) - Direct SQL execution
# ===================================================================
step_name = "Audit dim_product"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/dim_product/create_audit_dim_product_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 5B: Validation dim_product (Gold) - Direct SQL execution
# ===================================================================
step_name = "Validation dim_product"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/validation/validation_dim_product_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 6: Create dim_expected_assortment (Gold) - Direct SQL execution
# ===================================================================
step_name = "Create dim_expected_assortment"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/dim_expected_assortment/create_dim_expected_assortment_gold.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# STEP 6A: Validation dim_expected_assortment (Gold) - Direct SQL execution
# ===================================================================
step_name = "Validation dim_expected_assortment"
try:
    log_step(step_name, "START")
    with open("/Workspace/Users/diego.mayorgacapera@gmail.com/.bundle/BI_Market_Visibility/dev/files/src/gold/validation/validation_dim_expected_assortment.sql", "r") as f:
        sql_query = f.read()
    spark.sql(sql_query)
    log_step(step_name, "SUCCESS")
except Exception as e:
    log_step(step_name, "FAIL", str(e))
    raise e

# %%
# ===================================================================
# END OF GOLD ORCHESTRATOR
# ===================================================================
log_step("Gold Orchestrator", "END", "Gold layer orchestration completed")
